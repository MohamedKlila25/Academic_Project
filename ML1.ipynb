# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedKlila25/git_project-/blob/main/ML1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
#plt.subplot(n_lignes, n_colonnes, index)
#figsize=(L, H)
#np.random.seed(42)
x=np.random.randn(1000)
y=np.random.randn(1000)
print(x.shape)
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.plot(y,x)
plt.show()
# Out:
# (1000,)
